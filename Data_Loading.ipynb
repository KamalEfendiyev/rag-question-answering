# %%
# !pip install -q sentence-transformers faiss-cpu rank_bm25 datasets

from datasets import load_dataset

dataset = load_dataset("squad", split="train[:2000]")  # небольшой кусок

documents = list(set(dataset['context']))  # уникальные тексты
queries = dataset['question']
answers = dataset['answers']
